# %% [markdown]
# # open file and reade it

# %%
import pandas as pd 
df=pd.read_csv('C:\\Users\\masrra\\Desktop\\data2.csv') 
df
# Out:
#                   Column1                         Column2    Column3  \
# 0                   Title                        Location      Price
# 1          Villa for sale              Prins Karellaan 13    € 1,650
# 2          House for sale  Lembergsesteenweg 67 Box lot 2  € 419,000
# 3          House for sale  Lembergsesteenweg 67 Box lot 1  € 459,000
# 4          House for sale                Ruelle Hierby 17  € 149,000
# ...                   ...                             ...        ...
# 10183      Villa for sale                        Laar 196  € 599,900
# 10184    Mansion for sale               1030 — Schaerbeek  € 729,000
# 10185  Apartment for sale                 1370 — Jodoigne  € 150,000
# 10186  Penthouse for sale            Kustlaan 111 Box 6/7    € 2,795
# 10187      House for sale              Chemin du Tombeu 6  € 980,000
#
#                     Column4          Column5    Column6         Column7  \
# ...

# %% [markdown]
# # Name the columns

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 
df=pd.read_csv('C:\\Users\\masrra\Desktop\data2.csv')
df.rename(columns={'Column1':'property'},inplace=True)
df.rename(columns={'Column2':'Location'},inplace=True)
df.rename(columns={'Column3':'Price'},inplace=True)
df.rename(columns={'Column4':'Area'},inplace=True)
df.rename(columns={'Column5':'Number_of_Rooms'},inplace=True)
df.rename(columns={'Column6':'Furnished'},inplace=True)
df.rename(columns={'Column7':'Kitchen type'},inplace=True)
df.rename(columns={'Column8':'Status'},inplace=True)
df.rename(columns={'Column9':'Garden surface'},inplace=True)
df.rename(columns={'Column10':'Swimming Pool'},inplace=True)
df = df.drop(0)


df
# Out:
#                  property                        Location      Price  \
# 1          Villa for sale              Prins Karellaan 13    € 1,650
# 2          House for sale  Lembergsesteenweg 67 Box lot 2  € 419,000
# 3          House for sale  Lembergsesteenweg 67 Box lot 1  € 459,000
# 4          House for sale                Ruelle Hierby 17  € 149,000
# 5          House for sale             Rue Petite Voie 176  € 149,000
# ...                   ...                             ...        ...
# 10183      Villa for sale                        Laar 196  € 599,900
# 10184    Mansion for sale               1030 — Schaerbeek  € 729,000
# 10185  Apartment for sale                 1370 — Jodoigne  € 150,000
# 10186  Penthouse for sale            Kustlaan 111 Box 6/7    € 2,795
# 10187      House for sale              Chemin du Tombeu 6  € 980,000
#
#                        Area Number_of_Rooms Furnished    Kitchen type  \
# ...

# %% [markdown]
# # classify property to house ,apartement and others

# %%
df['property'].value_counts()==1
# Out:
# House for sale                                    False
# Villa for sale                                    False
# Apartment block for sale                          False
# Apartment for sale                                False
# Mixed-use building for sale                       False
#                                                   ...
# CLOS DES TROIS CHENES MAISONS - TREVI RASQUAIN     True
# CLOS DES TROIS CHENES - TREVI LIEGE - MAISONS      True
# ARBOR - Otegem                                     True
# Nieuwbouwproject Dahlia                            True
# Echte parkwoningen vlakbij centrum Tielt           True
# Name: property, Length: 197, dtype: bool

# %% [markdown]
# # clean the property

# %% [markdown]
# # first method

# %%
df['property'].replace(['Exceptional property for sale','CLOS DES TROIS CHENES MAISONS - TREVI RASQUAIN','CLOS DES TROIS CHENES - TREVI LIEGE - MAISONS ','ARBOR - Otegem','Nieuwbouwproject Dahlia','BEN-woningen te Herentals '],['OTHERS','OTHERS','OTHERS','OTHERS','OTHERS','OTHERS'],inplace=True)
df['property'].replace(['New real estate project - Houses for sale','Domaine de Limonval','CLOS DES TROIS CHENES - TREVI LIEGE - MAISONS','Adolphe Hullebroeckstraat','Combattants de Templeuve','BEN-woningen te Herentals'],['OTHERS','OTHERS','OTHERS','OTHERS','OTHERS','OTHERS'],inplace=True)
df['property'].replace(['Town-house for sale','Lotissement "Ann-Sophie C','Kerkstraat - Zwevegem','Lotissement Signeulx','Burenberg Uphill','809'],['OTHERS','OTHERS','OTHERS','OTHERS','OTHERS','OTHERS'],inplace=True)
df['property'].replace(['Ground floor for sale','CLOS DU ROGNAC FLEMALLE Phase 1','Clos des Etangs','Ten Amershove',"Luxe villa's Zoute",'Residentie Alex II'],['OTHERS','OTHERS','OTHERS','OTHERS','OTHERS','OTHERS'],inplace=True)
df['property'].replace(['Bungalow for sale','Nijven 27 Oppuurs',"'Eglegem Sunset'",'Sluisstraat','The Revelation','Woningen Rosalie'],['OTHERS','OTHERS','OTHERS','OTHERS','OTHERS','OTHERS'],inplace=True)
df['property'].replace(['Farmhouse for sale','Quartier Champ Delvigne','"Clos du verger"','MOULIN BLANC','Pré à la Planche Lots 7 à 15','Woonerf Bachtekerkweg' ],['OTHERS','OTHERS','OTHERS','OTHERS','OTHERS','OTHERS'],inplace=True)
df['property'].replace(['Country house for sale',"Maison - Le haut d'Hondzo","LES COTEAUX D'ERBONNE - MONT FALISE PHASE 1 MAISON",'Residentie Theresianenhof','Bois de la Pierre','Domaine du Fort'],['OTHERS','OTHERS','OTHERS','OTHERS','OTHERS','OTHERS'],inplace=True)
df['property'].replace(['Duplex for sale','"Moulin Blanc" Villas','Bottelarij','De Confiserie - gebouw H','WONINGEN I','Townhouses'],['OTHERS','OTHERS','OTHERS','OTHERS','OTHERS','OTHERS'],inplace=True)
df['property'].replace(['Villa for sale','Mansion for sale','Penthouse for sale','Mixed-use building for sale','Simmendans','Leeuwhof','Residentie Berghof','TONGRE NOTRE DAME - 8 maisons','Echte parkwoningen vlakbij centrum Tielt' ],['OTHERS','OTHERS','OTHERS','OTHERS','OTHERS','OTHERS','OTHERS','OTHERS','OTHERS'],inplace=True)
df
# Out:
#                  property                        Location      Price  \
# 1                  OTHERS              Prins Karellaan 13    € 1,650
# 2          House for sale  Lembergsesteenweg 67 Box lot 2  € 419,000
# 3          House for sale  Lembergsesteenweg 67 Box lot 1  € 459,000
# 4          House for sale                Ruelle Hierby 17  € 149,000
# 5          House for sale             Rue Petite Voie 176  € 149,000
# ...                   ...                             ...        ...
# 10183              OTHERS                        Laar 196  € 599,900
# 10184              OTHERS               1030 — Schaerbeek  € 729,000
# 10185  Apartment for sale                 1370 — Jodoigne  € 150,000
# 10186              OTHERS            Kustlaan 111 Box 6/7    € 2,795
# 10187      House for sale              Chemin du Tombeu 6  € 980,000
#
#                        Area Number_of_Rooms Furnished    Kitchen type  \
# ...

# %% [markdown]
# # second method

# %%
for i,rows in df.iterrows():
#for i in df.iteritems():
        property = df.iloc[:, 0]
        if i =='House for sale':
            continue
        elif i=='Apartment for sale':
            continue
        else: rows=='OTHERS'
property
# Out:
# 1                    OTHERS
# 2            House for sale
# 3            House for sale
# 4            House for sale
# 5            House for sale
#                 ...
# 10183                OTHERS
# 10184                OTHERS
# 10185    Apartment for sale
# 10186                OTHERS
# 10187        House for sale
# Name: property, Length: 10187, dtype: object

# %%
property=df['property'].value_counts()
property

# %%
df['property'].value_counts().plot(kind='pie')

# %%
df.shape
# Out:
# (10187, 10)

# %% [markdown]
# # clean number of rooms

# %%
df['Number_of_Rooms'].value_counts()==1
# Out:
# 3 bedrooms                            False
# 4 bedrooms                            False
# 2 bedrooms                            False
# 5 bedrooms                            False
# 6 bedrooms                            False
#                                       ...
# 400 m² square meters livable space     True
# 429 m² square meters livable space     True
# 275 m² square meters of land           True
# 5 bathrooms                            True
# 449 m² square meters of land           True
# Name: Number_of_Rooms, Length: 103, dtype: bool

# %%
#Delete boolean value
df = df[df.Number_of_Rooms!=False ]
df
# Out:
#                  property                        Location      Price  \
# 1                  OTHERS              Prins Karellaan 13    € 1,650
# 2          House for sale  Lembergsesteenweg 67 Box lot 2  € 419,000
# 3          House for sale  Lembergsesteenweg 67 Box lot 1  € 459,000
# 4          House for sale                Ruelle Hierby 17  € 149,000
# 5          House for sale             Rue Petite Voie 176  € 149,000
# ...                   ...                             ...        ...
# 10183              OTHERS                        Laar 196  € 599,900
# 10184              OTHERS               1030 — Schaerbeek  € 729,000
# 10185  Apartment for sale                 1370 — Jodoigne  € 150,000
# 10186              OTHERS            Kustlaan 111 Box 6/7    € 2,795
# 10187      House for sale              Chemin du Tombeu 6  € 980,000
#
#                        Area Number_of_Rooms Furnished    Kitchen type  \
# ...

# %%
df['Number_of_Rooms'].value_counts()
# Out:
# 3 bedrooms                            3957
# 4 bedrooms                            2236
# 2 bedrooms                            1481
# 5 bedrooms                             989
# 6 bedrooms                             446
#                                       ...
# 400 m² square meters livable space       1
# 429 m² square meters livable space       1
# 275 m² square meters of land             1
# 5 bathrooms                              1
# 449 m² square meters of land             1
# Name: Number_of_Rooms, Length: 103, dtype: int64

# %%
df['Number_of_Rooms'] = df['Number_of_Rooms'].str.extract(r'(\d+)').astype(int)


df
# Out:
#                  property                        Location      Price  \
# 1                  OTHERS              Prins Karellaan 13    € 1,650
# 2          House for sale  Lembergsesteenweg 67 Box lot 2  € 419,000
# 3          House for sale  Lembergsesteenweg 67 Box lot 1  € 459,000
# 4          House for sale                Ruelle Hierby 17  € 149,000
# 5          House for sale             Rue Petite Voie 176  € 149,000
# ...                   ...                             ...        ...
# 10183              OTHERS                        Laar 196  € 599,900
# 10184              OTHERS               1030 — Schaerbeek  € 729,000
# 10185  Apartment for sale                 1370 — Jodoigne  € 150,000
# 10186              OTHERS            Kustlaan 111 Box 6/7    € 2,795
# 10187      House for sale              Chemin du Tombeu 6  € 980,000
#
#                        Area  Number_of_Rooms Furnished    Kitchen type  \
# ...

# %%
df2=df[df['Number_of_Rooms'] <6]
df2
# Out:
#                  property                        Location      Price  \
# 1                  OTHERS              Prins Karellaan 13    € 1,650
# 2          House for sale  Lembergsesteenweg 67 Box lot 2  € 419,000
# 3          House for sale  Lembergsesteenweg 67 Box lot 1  € 459,000
# 4          House for sale                Ruelle Hierby 17  € 149,000
# 5          House for sale             Rue Petite Voie 176  € 149,000
# ...                   ...                             ...        ...
# 10182              OTHERS           Oostmalsesteenweg 295  € 635,000
# 10183              OTHERS                        Laar 196  € 599,900
# 10185  Apartment for sale                 1370 — Jodoigne  € 150,000
# 10186              OTHERS            Kustlaan 111 Box 6/7    € 2,795
# 10187      House for sale              Chemin du Tombeu 6  € 980,000
#
#                        Area  Number_of_Rooms Furnished    Kitchen type  \
# ...

# %%
df2['Number_of_Rooms'].value_counts()
# Out:
# 3    4015
# 4    2241
# 2    1520
# 5     990
# 1     346
# Name: Number_of_Rooms, dtype: int64

# %%
df2['Number_of_Rooms'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Number_of_Rooms'>

# %% [markdown]
# # clean the price column

# %%
df2['Price'] = df2['Price'].str.replace('[,]', '')
df2['Price'] = df2['Price'].str.replace('[€]', '')
df2['Area'] = df2['Area'].str.replace('[m²]', '')
df2
# Out:
# C:\Users\masrra\anaconda3\envs\tf\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.
# C:\Users\masrra\anaconda3\envs\tf\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\masrra\anaconda3\envs\tf\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#
# C:\Users\masrra\anaconda3\envs\tf\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df2['Price'] =pd.to_numeric(df2['Price'])
df2
# Out:
# C:\Users\masrra\anaconda3\envs\tf\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                  property                        Location   Price  \
# 1                  OTHERS              Prins Karellaan 13    1650
# 2          House for sale  Lembergsesteenweg 67 Box lot 2  419000
# 3          House for sale  Lembergsesteenweg 67 Box lot 1  459000
# 4          House for sale                Ruelle Hierby 17  149000
# 5          House for sale             Rue Petite Voie 176  149000
# ...                   ...                             ...     ...
# 10182              OTHERS           Oostmalsesteenweg 295  635000
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9112 entries, 1 to 10187
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property         9112 non-null   object
#  1   Location         9112 non-null   object
#  2   Price            9112 non-null   int64
#  3   Area             9112 non-null   object
#  4   Number_of_Rooms  9112 non-null   int32
#  5   Furnished        9112 non-null   object
#  6   Kitchen type     9112 non-null   object
#  7   Status           9112 non-null   object
#  8   Garden surface   9112 non-null   object
#  9   Swimming Pool    9112 non-null   object
# dtypes: int32(1), int64(1), object(8)
# memory usage: 747.5+ KB

# %%
df2['Price'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # clean the Garden surface

# %%
df2['Garden surface'] = df2['Garden surface'].str.replace('[m²]', '')
df2['Garden surface'] = df2['Garden surface'].str.replace('[450m]', '')
df2['Garden surface'] = df2['Garden surface'].str.replace('[450 m²]', '')
#'450 m² '
df2['Garden surface'] = df2['Garden surface'].str.replace('[1 square eter]', '')
df2['Garden surface'] = df2['Garden surface'].str.replace('', '.')
#del df[,]
#df2.at[110, ''] = 0
#df2['Garden surface'] = pd.to_datetime(df["Garden surface"])
#df2['Garden surface'] = df2['Garden surface'].str.replace('', '')
#'1 square eter'
df2
# Out:
# C:\Users\masrra\anaconda3\envs\tf\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.
# C:\Users\masrra\anaconda3\envs\tf\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\masrra\anaconda3\envs\tf\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#
# C:\Users\masrra\anaconda3\envs\tf\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df2['Garden surface'].unique()
# Out:
# array(['.', '.3.3.', '.3.', '.7.', '.9.2.', '.2.3.', '.2.', '.3.2.',
#        '.9.', '.3.6.9.', '.3.6.', '.6.', '.3.9.', '.3.2.3.', '.3.8.',
#        '.8.', '.8.9.', '.7.9.', '.2.2.', '.9.6.', '.7.6.', '.2.8.',
#        '.2.6.', '.9.8.', '.8.7.3.', '.2.7.3.', '.9.3.', '.8.8.', '.2.9.',
#        '.2.2.8.', '.7.8.', '.3.3.7.', '.2.7.', '.2.3.8.', '.7.7.8.',
#        '.3.2.6.', '.7.6.3.', '.3.3.2.', '.7.7.6.9.', '.9.7.', '.6.8.',
#        '.6.6.', '.8.7.9.', '.8.2.', '.6.3.', '.6.2.', '.2.8.9.',
#        '.2.2.3.', '.3.7.', '.7.7.', '.7.3.', '.2.2.2.', '.7.2.',
#        '.6.6.7.', '.8.7.', '.7.9.3.', '.9.9.', '.3.8.7.', '.6.2.3.',
#        '.6.7.', '.2.6.7.', '.3.8.6.', '.3.2.3.2.', '.6.6.6.', '.8.8.3.',
#        '.2.6.2.', '.6.9.', '.6.8.8.', '.2.6.8.', '.8.6.', '.2.6.6.',
#        '.2.7.7.6.', '.8.3.', '.9.6.6.', '.3.3.6.', '.7.9.8.', '.3.9.2.',
#        '.2.3.7.', '.3.8.3.', '.9.6.3.', '.6.9.2.', '.2.8.2.', '.3.2.7.',
# ...

# %%
#df2['Garden surface'].astype('int32')
#df2
df2['Garden surface'] = df2['Garden surface'].apply("int")
df2
#df2['Garden surface'] = pd.to_numeric(df2['Garden surface']).astype("Int32")
#df2
#df2["Garden surface"] = [int(x) if x.isnumeric() else x for x in df2["Garden surface"] ]
#df2
#df2["Garden surface"] = pd.to_numeric(df["Garden surface"], errors='coerce')
#df2
#df2["Garden surface"] = pd.to_numeric(df["Garden surface"])
#df2
#for i in df['Garden surface']:
 #   for j in range(0, 9112): #rows = 9112
  #      df[i][j] = int(df[i][j])
#df2['Garden surface'].astype(str).astype(int)
#df2
#df2['Garden surface']=int(df2['Garden surface'])
#df2
#df2['Garden surface'] = df2['Garden surface'].astype(str).astype(int)
#df2

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9112 entries, 1 to 10187
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property         9112 non-null   object
#  1   Location         9112 non-null   object
#  2   Price            9112 non-null   int64
#  3   Area             9112 non-null   object
#  4   Number_of_Rooms  9112 non-null   int32
#  5   Furnished        9112 non-null   object
#  6   Kitchen type     9112 non-null   object
#  7   Status           9112 non-null   object
#  8   Garden surface   9112 non-null   object
#  9   Swimming Pool    9112 non-null   object
# dtypes: int32(1), int64(1), object(8)
# memory usage: 747.5+ KB

# %%
df2['Garden surface'].plot(kind='hist')

# %%
df2.describe()
# Out:
#                Price  Number_of_Rooms
# count    9112.000000      9112.000000
# mean   318278.247805         3.220478
# std    191379.980872         0.975051
# min      1000.000000         1.000000
# 25%    199000.000000         3.000000
# 50%    290000.000000         3.000000
# 75%    398000.000000         4.000000
# max    999500.000000         5.000000

# %%
1-Which variable is the target ? the price of the property
2-How many rows and columns ? according to df.shape I have 9112 rows and 10columns
3-What is the correlation between the variables and the target ? (Why might that be?) I think the variables are the features 
that make us to predict the target
4-What is the correlation between the variables and the other variables ? (Why?)one of the variable considered as a features
and the others considered as a features
5-Which variables have the greatest influence on the target ?number of rooms,area,price
6-Which variables have the least influence on the target ?kitchen type,swimming pool,garden surface 
7-How many qualitative and quantitative variables are there ? How would you transform these values into numerical values ?
I transfer the value to numerical value by two ways,using astype(int) or pd.to_numeric().
quantity variables are number of rooms,price,area.
quality variables are property,status,swimming pool,furnished,location 

8-Percentage of missing values per column ?in my data there is no missing data or null data

# %%
Are there any outliers? If yes, which ones and why?yes ,like number of rooms 400 .it is unlogic and it requires to clean it 
Which variables would you delete and why ?if you mean cells ,all the outlierss required to delete it 
and if you mean columns ,I think kitchen type,garden surface  
In your opinion, which 5 variables are the most important and why?the 5 most important values are price ,number of rooms
,location ,area,property

# %%
In your opinion, which model of machine learning could solve the task of predicting the sales? Random forest according to google and multiple linear regression according to content
because I should use two features like number of rooms and property for example to predict the price (target)

# %%
df_new = df2[['property','Number_of_Rooms', 'Price']]
df_new
# Out:
#                  property  Number_of_Rooms   Price
# 1                  OTHERS                4    1650
# 2          House for sale                3  419000
# 3          House for sale                3  459000
# 4          House for sale                2  149000
# 5          House for sale                5  149000
# ...                   ...              ...     ...
# 10182              OTHERS                4  635000
# 10183              OTHERS                4  599900
# 10185  Apartment for sale                1  150000
# 10186              OTHERS                3    2795
# 10187      House for sale                5  980000
#
# [9112 rows x 3 columns]

# %%
df_new.describe()
# Out:
#        Number_of_Rooms          Price
# count      9112.000000    9112.000000
# mean          3.220478  318278.247805
# std           0.975051  191379.980872
# min           1.000000    1000.000000
# 25%           3.000000  199000.000000
# 50%           3.000000  290000.000000
# 75%           4.000000  398000.000000
# max           5.000000  999500.000000
